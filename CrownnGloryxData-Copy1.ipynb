# %%
import pandas as pd
import numpy as np
import random as r 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#create a list that automates the values for each 
#column or category

lolo = 1015000
ID_numbers = []
for i in range(76):
    lolo += 1
    ID_numbers.append(str(lolo))

starting_date = '09/05/2023'
date = []
for i in range(76):
    date.append(starting_date)

starting_time = 900
time = []
for i in range(76):
    starting_time += 15
    time.append(starting_time)

Cus = 20010050
CID_numbers = []
for i in range(76):
    Cus += 1
    CID_numbers.append(Cus)

# %%
#Create more products
product = ['Mielle Rosemary Oil', 'Mielle Edge Control',
          'Miss Jessies Pillow Soft Curls', 'Design Essentials Lathering Shampoo',
          'Kaliedoscope Hair Growth Serum', 'Eco Styler Coconut Oil Gel',
          'Shea Moisture Curl Smoothing Milk', 'Babyliss Hair Flat Iron',
          'Hold Me Down! Lace Glue', 'Got2B Freeze Spray', 'Lace Tint Mousse',
          'Orignal Blue Magic Grease', 'Jamaican Black Castor Oil',
          'Doo Gro Oil', 'Knot Today! Detangling Condotioner',
          'Design Essentials Blow Dry 4 step Kit', 'Design Essentials Anti Itch Pomade',
          'Mielle Strengthening Condotioner', 'Shea Butter', 'Cocoa Butter',
           'Palmers Body Oil', 'LA Girl Pro Concealer', 'Paddle Brush', 'Combs',
           'Xpressions Braiding Hair-Cocoa','Xpressions Braiding Hair-613',
           'Xpressions Braiding Hair-Cajun Spice','Xpressions Braiding Hair-Jet Black',
           'Shine n Jam Braiding Grease', 'Eco Styler Pink Gel', 'Hot comb', 'Mannequin Head',
           'SheaMoisture Jamaican Black Castor Oil Shampoo', 'Cantu Shea Butter Leave-In Conditioning Cream', 'African Pride Olive Miracle Deep Conditioner','ORS Olive Oil Edge Control Gel',
    'Taliah Waajid Protective Styles Bamboo and Coconut Milk',
    'Eco Styler Professional Styling Gel',
    'Aunt Jackies Knot On My Watch Detangling Therapy',
    'Carols Daughter Black Vanilla Moisture & Shine Hair Smoothie',
    'Mizani 25 Miracle Milk Leave-In Conditioner',
    'As I Am Coconut CoWash Cleansing Conditioner',
    'Creme of Nature Argan Oil Perfect Edges',
    'Dark and Lovely Au Naturale Anti-Shrinkage Curl Defining Crème Glaze',
    'ORS Olive Oil Incredibly Rich Oil Moisturizing Hair Lotion',
    'Alikay Naturals Lemongrass Leave-In Conditioner',
    'Camille Rose Naturals Curl Maker',
    'Jane Carter Solution Curl Defining Cream',
    'SheaMoisture Coconut & Hibiscus Curl Enhancing Smoothie',
    'Mielle Organics Pomegranate & Honey Leave-In Conditioner',
    'Aphogee Two-Step Protein Treatment',
    'Cantu Shea Butter for Natural Hair Define & Shine Custard',
    'ORS Olive Oil Replenishing Conditioner',
    'TGIN Miracle RepaiRx Deep Hydrating Hair Mask',
    'Creme of Nature Argan Oil Strength & Shine Leave-In Conditioner',
    'Carols Daughter Mimosa Hair Honey',
    'African Pride Moisture Miracle Leave-In Cream',
    'Design Essentials Natural Almond & Avocado Curl Enhancing Mousse',
    'Aunt Jackies Flaxseed Recipes Curl Mane-Tenance Defining Curl Whip',
    'SheaMoisture Raw Shea Butter Deep Treatment Masque',
    'Mizani True Textures Curl Enhancing Lotion',
    'Eco Styler Olive Oil Styling Gel',
    'ORS Monoi Oil Anti-Breakage Leave-In Conditioning Crème',
    'Alikay Naturals Essential 17 Hair Growth Oil',
    'Camille Rose Naturals Almond Jai Twisting Butter',
    'Taliah Waajid Curly Curl Cream',
    'Aphogee Curlific Texture Treatment',
    'Cantu Shea Butter for Natural Hair Sulfate-Free Cleansing Cream Shampoo',
    'African Pride Black Castor Miracle Hair & Scalp Sealing Oil',
    'ORS Olive Oil Nourishing Sheen Spray','ORS Olive Oil Nourishing Sheen Spray',
    'As I Am Double Butter Cream',
    'Jane Carter Solution Nourish & Shine',
    'SheaMoisture Manuka Honey & Mafura Oil Intensive Hydration Masque',
    'Creme of Nature Argan Oil Perfect 7 Leave-In Treatment',
    'Mielle Organics Babassu Oil & Mint Deep Conditioner',
        ]

#create a random generator and add them to price
price = [r.uniform(5.99, 35.99) for _ in range(76)]   


total_price = [r.uniform(21.99, 55.99) for _ in range(76)]

# %%
#Create a dictionary with the future 
#columns as keys, and each row 
#will be a value that maps to the key

#For example
#disney = {'name': ['Mickey', 'Minnie', 'Pluto'],
#             'gender': ['m', 'f', 'n'],
#             'age': [95, 95, 93],}

#name, gender, and age are the future 
#column names. Mickey will be the 0th row
#and his gender and age will be vertically
#underneath etc.. so it will read:
#Mickey, m, 95

#Make a dictionary named Day_Of_Transactions
#That has the keys as the future col names needed
#Each key should map to a list that automatically
#assigns the numbers needed
'''
Day_Of_Transactions = { 'TransactionID':, 
                       'Date':, 
                       'Time':, 
                       'CustomerID':,
                       'Product':,
                       'Product_Category':,
                       'Price':,
                       'Quantity':,
                       'Total_Amount':,
                       'Payment_Method':,
                       'Online_Instore':,
    
}
'''
Day_Of_Transactions = { 'TransactionID':ID_numbers, 
                       'Date':date, 
                       'Time':time, 
                       'CustomerID': CID_numbers,
                       'Product':product,
                       'Price':price,
                       'Total_Transaction': total_price,
                      }

# %%
CNG_DF = pd.DataFrame(Day_Of_Transactions)
CNG_DF
# Out:
#    TransactionID        Date  Time  CustomerID  \
# 0        1015001  09/05/2023   915    20010051
# 1        1015002  09/05/2023   930    20010052
# 2        1015003  09/05/2023   945    20010053
# 3        1015004  09/05/2023   960    20010054
# 4        1015005  09/05/2023   975    20010055
# ..           ...         ...   ...         ...
# 71       1015072  09/05/2023  1980    20010122
# 72       1015073  09/05/2023  1995    20010123
# 73       1015074  09/05/2023  2010    20010124
# 74       1015075  09/05/2023  2025    20010125
# 75       1015076  09/05/2023  2040    20010126
#
#                                               Product      Price  \
# 0                                 Mielle Rosemary Oil  31.447444
# 1                                 Mielle Edge Control  27.502548
# 2                      Miss Jessies Pillow Soft Curls  17.400312
# 3                 Design Essentials Lathering Shampoo  34.946312
# 4                      Kaliedoscope Hair Growth Serum  19.177234
# ...

# %%
CNG_DF.tail()
# Out:
#    TransactionID        Date  Time  CustomerID  \
# 71       1015072  09/05/2023  1980    20010122
# 72       1015073  09/05/2023  1995    20010123
# 73       1015074  09/05/2023  2010    20010124
# 74       1015075  09/05/2023  2025    20010125
# 75       1015076  09/05/2023  2040    20010126
#
#                                               Product      Price  \
# 71                        As I Am Double Butter Cream   6.308667
# 72               Jane Carter Solution Nourish & Shine  23.855584
# 73  SheaMoisture Manuka Honey & Mafura Oil Intensi...  30.687599
# 74  Creme of Nature Argan Oil Perfect 7 Leave-In T...  26.955494
# 75  Mielle Organics Babassu Oil & Mint Deep Condit...  19.621718
#
#     Total_Transaction
# 71          53.431696
# 72          35.517257
# 73          32.752462
# 74          34.788721
# 75          49.137798

# %%
CNG_DF.dtypes
# Out:
# TransactionID         object
# Date                  object
# Time                   int64
# CustomerID             int64
# Product               object
# Price                float64
# Total_Transaction    float64
# dtype: object

# %%
CNG_DF['Price'].mean()
# Out:
# 20.59814541814918

# %%
CNG_DF['Total_Transaction'].mean()
# Out:
# 39.656002177146135

# %%
# list of payment methods
pm = ['Apple Pay', 'Cash', 'Debit', 'Credit']
weights = [0.4, 0.2, 0.3, 0.31]

#List of pickup options
PO = ['Online','In Store']
w = [0.62,(1-0.62)]

# Add a new column 'Payment method' with random payment methods
CNG_DF['Payment_Method'] = r.choices(pm, weights=weights, k=76)

# Add a new column 'Pickup_methods' with random pickup methods
CNG_DF['Pickup_Method'] = r.choices(PO, weights=w, k=76)


CNG_DF
# Out:
#    TransactionID        Date  Time  CustomerID  \
# 0        1015001  09/05/2023   915    20010051
# 1        1015002  09/05/2023   930    20010052
# 2        1015003  09/05/2023   945    20010053
# 3        1015004  09/05/2023   960    20010054
# 4        1015005  09/05/2023   975    20010055
# ..           ...         ...   ...         ...
# 71       1015072  09/05/2023  1980    20010122
# 72       1015073  09/05/2023  1995    20010123
# 73       1015074  09/05/2023  2010    20010124
# 74       1015075  09/05/2023  2025    20010125
# 75       1015076  09/05/2023  2040    20010126
#
#                                               Product      Price  \
# 0                                 Mielle Rosemary Oil  31.447444
# 1                                 Mielle Edge Control  27.502548
# 2                      Miss Jessies Pillow Soft Curls  17.400312
# 3                 Design Essentials Lathering Shampoo  34.946312
# 4                      Kaliedoscope Hair Growth Serum  19.177234
# ...

# %%
total_by_paymen = CNG_DF[['Total_Transaction','Payment_Method']]
total_by_payment = total_by_paymen[total_by_paymen['Total_Transaction']> 20]
total_by_payment
# Out:
#     Total_Transaction Payment_Method
# 0           32.257016           Cash
# 1           49.637145         Credit
# 2           24.687699      Apple Pay
# 3           46.301007         Credit
# 4           55.874561          Debit
# ..                ...            ...
# 71          53.431696      Apple Pay
# 72          35.517257         Credit
# 73          32.752462         Credit
# 74          34.788721           Cash
# 75          49.137798         Credit
#
# [76 rows x 2 columns]

# %%
# Group total_by_payment by payment options
grouped = total_by_payment.groupby('Payment_Method')['Total_Transaction'].sum().reset_index()
# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(grouped['Payment_Method'], grouped['Total_Transaction'])
plt.xlabel('Payment Method')
plt.ylabel('Total Transaction Amount')
plt.title('Total Transaction Amounts by Payment Method')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# This code will create  a bar chart showing 
#the total transaction amounts for each payment method

# %%
# Calculate the total sales for each payment method
total_sales = grouped['Total_Transaction'].sum()

# Calculate the percentage of total sales for each payment method
grouped['Percentage'] = (grouped['Total_Transaction'] / total_sales) * 100

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(grouped['Percentage'], labels=grouped['Payment_Method'], autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Percentage of Total Sales by Payment Method')
plt.show()
# This code will create a pie chart showing the percentage 
# distribution of total sales among different payment methods
