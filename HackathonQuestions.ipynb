# %%
  import math as m 
  import random as r

# %%
def getName():
  import random
  info = {}
  count = 0

  while True:
    name = input("Enter your name: ")
    ID = random.randint(101000,101999)
    info[name] = str(ID)
    
    count += 1
    if count % 2 and count > 1:
      ask = input("Do you wish to continue? ")
      if ask == 'yes':
        continue
      elif ask == "no":
        break

    
  print(info)
  return info
  
#Given an integer, , perform the following conditional actions:

#If  is odd, print Weird
#If  is even and in the inclusive range of 2 to 5, print Not Weird
#If  is even and in the inclusive range of 6 to 20, print Weird
#If  is even and greater than 20, print Not Weird

def weird(n):
  

  
  nw = "Not Weird"
  w = "Weird"
  n = r.randint(0,100)
  print("This is n", n)
  #NW
  while (n % 2) == 0:
    if n in range(1,6) or n > 20:
      print(nw)
    elif n in range(5,21):
      print(w)
    break
  #W
  while (n % 2) != 0:
    print(w)
    break
  
def addnumbers():

  #The first line contains the sum of the two numbers.
  #The second line contains the difference of the two numbers (first - second).
  #The third line contains the product of the two numbers.
  a = r.randint(0,10000000000)
  b = r.randint(0,10000000000)
  print(a+b)
  if a > b: 
    print(a-b) 
  else: 
    print(b-a)
  print(a*b)
  

def listofsquares():
  #The list of non-negative integers that are less than  is 3. Print the square of each number [0,1,2] on a separate line. 1<n<20
  n = r.randint(0,21)
  while True:
    nlist = []
    for number in range(n):
      if number < n and number > -1:
        nlist.append(int(number))
    #print("This is n:", n)
    #print(nlist)
        
    #newlist = []
    for element in nlist:
      m = element ** 2
      #newlist.append(int(m))
      print(m)

    
    break


def nonleapyear():
  #In the Gregorian calendar, three conditions are used to identify leap years:

  #The year can be evenly divided by 4, is a leap year, unless:
  #The year can be evenly divided by 100, it is NOT a leap year, unless:
  #The year is also evenly divisible by 400. Then it is a leap year.
  #This means that in the Gregorian calendar, the years 2000 and 2400 are leap years,     while 1800, 1900, 2100, 2200, 2300 and 2500 are NOT leap years
  nl = []
  for year in range(1899,3001):
    if ( year % 4) == 0: #Divisible by 4
      if (year % 100) == 0 and not (year % 400) == 0:#divisible by 100 but not 400
        nl.append(int(year))
  print(nl) #prints non leap years


def isleap(Year):

  
  while ( Year % 4) == 0: #Divisible by 4
    if (Year % 100) == 0:
      if (Year % 400) == 0:#divisible by 100 and 400
        print("Leap year")
      break
      #return True

  while ( Year % 4) != 0:
    print("Not leap")
    break
    #return False


  
def main():
  Year = 2016
  isleap(Year)
  '''
  n = 4
  weird(n)
  
  n = 22
  weird(n)
  
  n = 18
  weird(n)
  
  n = 3
  weird(n)
  
  n = 21
  weird(n)
  
  n = 19
  weird(n)
  '''
  
main()
