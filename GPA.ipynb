# %%
ut_arlington_gpa = 3.458
desired_gpa = 3.4 
#current_gpa = 2.9547
#3.458 + x= 3.4.  

#.   ______      3.458 + x = 3.4*2
#                  3.458x = 6.8
#                  _____________
#                       3.458
#                       x =
#       2

# %%
current_gpa = 0.0
while current_gpa <= 5.0:
    current_gpa += 0.1
    new_gpa = (current_gpa + ut_arlington_gpa) / 2
    
    if new_gpa >= desired_gpa:
        if current_gpa < 3.7:
            print("You need a GPA of",round(current_gpa,2),"To get a cummlative GPA of", round(new_gpa,3))
   
    i = 0.0
    while i < 5.0:
        i += 0.1
        semester_gpa = (i + 2.9547) / 2
        if new_gpa > 3.5:
        #if (semester_gpa + current_gpa) / 2 > new_gpa:
            print("Your semester GPA needs to be ",round(semester_gpa,2), " enable to get a final GPA of ",round(new_gpa,3))
# Out:
# You need a GPA of 3.4 To get a cummlative GPA of 3.429
# You need a GPA of 3.5 To get a cummlative GPA of 3.479
# You need a GPA of 3.6 To get a cummlative GPA of 3.529
# Your semester GPA needs to be  1.53  enable to get a final GPA of  3.529
# Your semester GPA needs to be  1.58  enable to get a final GPA of  3.529
# Your semester GPA needs to be  1.63  enable to get a final GPA of  3.529
# Your semester GPA needs to be  1.68  enable to get a final GPA of  3.529
# Your semester GPA needs to be  1.73  enable to get a final GPA of  3.529
# Your semester GPA needs to be  1.78  enable to get a final GPA of  3.529
# Your semester GPA needs to be  1.83  enable to get a final GPA of  3.529
# Your semester GPA needs to be  1.88  enable to get a final GPA of  3.529
# Your semester GPA needs to be  1.93  enable to get a final GPA of  3.529
# Your semester GPA needs to be  1.98  enable to get a final GPA of  3.529
# Your semester GPA needs to be  2.03  enable to get a final GPA of  3.529
# ...
